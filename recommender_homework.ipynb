# %%
import pandas as pd
import numpy as np

# %%
#download the class movie reviews from here:
#https://docs.google.com/spreadsheets/d/17rCJzmWxqvAu9rkpkgt4ToccIlY4A1Ffuu1W9X3B8Ag/
#then read that in as a pandas dataframe

# %%
M = pd.read_csv("Movie Reviews - Sheet1.csv", index_col='Name')

# %%
M.shape
# Out:
# (105, 16)

# %%
M
# Out:
#                     American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                   4.0                                    NaN
# Aditya Dharmasagar              5.0                                    NaN
# Adrian Cavallaris               NaN                                    4.0
# Ahmed Muheebuddin               5.0                                    NaN
# Aishwarya reddy                 NaN                                    3.0
# Akhilesh                        NaN                                    NaN
# Andrew Webb                     4.0                                    3.0
# Anirudh                         3.0                                    4.0
# Anirudh Thota                   NaN                                    3.0
# anurag                          4.0                                    NaN
# Anusha Putta                    NaN                                    NaN
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ### Question 1:  What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:10]
# Out:
# [('Interstellar', 0.2178645563053444),
#  ('Malificent', 0.19789929184067265),
#  ('Divergent', 0.18271984148742279),
#  ('Unbroken', 0.17273639371993235),
#  ('Gone Girl', 0.12917557893423595),
#  ('Guardians of the Galaxy', 0.10623790358033861),
#  ('How to Train your Dragon 2', 0.094321109306395534),
#  ('The Lego Movie', 0.059384276314390326),
#  ('Godzilla', 0.048282487345933572),
#  ('The Hunger Games: Mockingjay - Part 1', 0.040894023196430006)]

# %% [markdown]
# These are the list of top 10 movies which are similar to the movie __The Fault in Our stars__.
#
# But the question asks about the most similar movie. Thus the first one from the array would be most similar.

# %%
recs[0]
# Out:
# ('Interstellar', 0.2178645563053444)

# %% [markdown]
# ### Question 2:  Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#the movies my friend/classmate has seen
my_ratings = M.ix['Shreya Kulkarni'].dropna()
#the movies She has rated the highest
my_ratings.sort_values(ascending=False)
#the name of the movie she has rated the highest
fav_movie = my_ratings.index[0]

# %%
fav_movie
# Out:
# 'American Sniper'

# %% [markdown]
# The movie which I should see according to my friend's experience is **American Sniper**

# %% [markdown]
# ### Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)
